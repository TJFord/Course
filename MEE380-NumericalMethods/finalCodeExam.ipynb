% %% [markdown]
% # MEE380 Final Exam
% ## May 6th, 2024, 2-3:50 pm, Submit the provided matlab skeleton file with your solution and a pdf generated by the matlab. Save both files as `YourFirstName_LastName.pdf` and `YourFirstName_LastName.m` or `YourFirstName_LastName.mlx`.
%
% 1. To evaluate the following integral $$\int_{0}^2(1-\cos x)dx$$
%    1. (3 points) find the results analytically
%    2. (5 points) use **three** point gauss quadrature to evaluate the integral, and calcuate the relative error. The three points are $x_i=[-\sqrt{\dfrac{3}{5}}, 0 , \sqrt{\dfrac{3}{5}}]$, and the weights are $w_i=[\dfrac{5}{9},\dfrac{8}{9},\dfrac{5}{9}]$
%
%    4. (5 points) use 1/3 simpson rule to evalute the integral, and calcuate the relative error
% 3.  (10 ponits) Please study and complete the provided skeleton code based on the newton's raphson iterative method to solve
% \begin{align}
%     (x-4)^2+(y-4)^2&=4\\
%     x^2+y^2&=16
% \end{align}
% with an initial guess of $(x_0,y_0)=(1,2)$. Besides your code, you should provide a short summary explaining how you break this complex problem into many simple steps. You have to code the Newton Raphson algorithm (you cannot use built-in function `fsolve`). Your solution to the roots should be saved as `x`, the number of iterations is saved as `it`.
%
%
% 2. Consider 1D heat transfer on an insulated wire of length $L=1$, both ends are embedded in ice ($T(0,t)=T(L,t)=0$).  The initial temperature is $T(x,0)=0.1\sin(\pi x)+\sin(2\pi x)$
%   \begin{align}
%     \dfrac{\partial T}{\partial t}=0.3 \dfrac{\partial^2 T}{\partial x^2}\\
% \end{align}
%     1. (6 points) Please use backward difference in time (implicit scheme) and central difference in space to discretize the partial differential equation, and simplify the equation in the format of $T_i^k=\text{SomeAlgebraicExpression}$  that can be used for gauss seidel iterative solver. Noted that $T_i^k$ is a short handed notation $T_i^k:=T(x_i,t_k)$, take a uniform grid with $dx=0.01$, and time step $dt=0.001$
%        <!-------------    3. (10 points) Use Gauss-seidel iterative method to solve the heat transfer problem, 4. (5 points) Plot the temperature profile over the domain at $t=[0.1,0.2,0.3]$ seconds on the same figure with different lines and Compare your numerical solution with the true analytical solution $T(x,t)=0.1\sin(\pi x)e^{-0.3\pi^2t}+\sin(2\pi x)e^{-1.2\pi^2t}$.
%         ----------->
%     2. (8 points) The analytical solution is $T(x,t)=0.1\sin(\pi x)e^{-0.3\pi^2t}+\sin(2\pi x)e^{-1.2\pi^2t}$. Please plot the temperature for  $dx=0.01$ at $t=[0, 0.1, 0.2]~s$ in the same figure with different line styles. Make sure you add legends for each curve and labels for each axis.
% 4. Consider launching an object vertically upwards, the equation of motion is
%    \begin{align}
%    \dfrac{d^2y}{dt^2}&=-g
%    \end{align}
% where $y$ is the coordinate of the object, $g=9.8~m/s^2$, with initial condition $y(0)=0, v(0)=1~m/s$
%     1. (4 points) Convert the 2nd order ordinary differential equations (ODE) into a set of 1st ODEs, $$\dfrac{d\mathbf{x}}{dt}=\mathbf{Ax+b}$$ where the unknown vector $\mathbf{x}=\begin{bmatrix}y\\v\end{bmatrix}$. You need to specify the matrix $\mathbf{A}$, vector $\mathbf{b}$ , and the initial conditions for $\mathbf{x}$.
%     2. (4 points) Solve the ODEs using analytical methods, and show your results for velocity $v$ and displacement $y$.
%     3. (12 points) Solve the ODEs using built-in function `ode45` for $y$ and $v$ for $0\le t\le 1~s$, plot them against time $t$. You can use `ode45` documentation to help you complete this exercise.
%     4. (bonus 10 points) Solve the ODEs using the fourth order runge kutta method for $y$ and $v$ for $0\le t\le 1~s$, plot them against time $t$.
