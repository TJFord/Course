# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ## Plan
# choose CV attached to the water surface.
# Conservation of Mass $$\dfrac{dm}{dt}=\dfrac{d}{dt}\int_{cv} \rho d\vee + \int_{cs}\rho \vec{V}\cdot \vec{n}dS$$
