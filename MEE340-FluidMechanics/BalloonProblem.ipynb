# %%
from pint import UnitRegistry
u=UnitRegistry(auto_reduce_dimensions=True)
import handcalcs.render
import math

# %% [markdown]
# A balloon is being inflated with a water supply of $0.6\, m^3/s$. Find the rate of growth of the radius at the instant when $R=0.5\,m$
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# # Thought process
