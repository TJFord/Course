# %% [markdown]
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# # Solution
# 1. CV
# 2. what equation?
# <!--$$\sum \vec{F}=\dfrac{d(m\vec{V})}{dt}=\dfrac{d}{dt}\int_{cv}{\rho\vec{V}}d\vee+\int_{cs}\rho\vec{V}(\vec{V}_r\cdot\vec{n})dA$$-->
# 3. LHS
# 4. RHS
