# %%
from pint import UnitRegistry
u=UnitRegistry(auto_reduce_dimensions=True)
import handcalcs.render
import math

# %% [markdown]
# ## Problem 2-83
# ## Statement
# 1. Drag force expresssion $F_d=?$
# 2. Drag force magnitude $F_d$ with $R = 0.08 m$, $L=20 m, u_{max}=3 m/s, \mu = 0.0010 kg/m\cdot s$
#
# ![image.png](attachment:image.png)
# ## Plan
#
# 1. Drag force can be calcuated as integral of shear force over the surface area, $$F_d=\int_A \tau dA$$
# ## Solution
