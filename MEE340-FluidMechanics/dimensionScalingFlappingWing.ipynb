# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There are a few confusions to point out in the image above.
# 1. `omega` is used as a relaxation number in lattice boltzmann (LB) simulation. For the flapping wing, the frequency is denoted as `freLB`.
# 2. `xSide = 2` is the wing length in x direction. In dimensionless LB units, it is `xSideLB` calculated as $\dfrac{xSide}{dx}=\dfrac{2}{0.111}=18$
# 3. the inlet velocity is `inletVelocity=1`, convert it to LB units is $\dfrac{inletVelocity}{dx/dt}$
# 4. the `inletVelocityLB` is scaled close to 1 for Paraview visualization $\dfrac{inletVelocityLB}{dt/dx}$

# %%
# max fluid velocity in ParaVie
from numpy import *
import handcalcs.render # render

# %%
# %%render
#
# A = 0.785398 # oscillating amplitude
# omega = 8.2e-5 # oscillating frequency
# dt = 0.00082
# dx = 0.11111
# timestep = 5e5 # check the last time step
# angle = 0.5*pi+A*sin(2*pi*omega*timestep*dt)
# dangle_dt = 2*pi*omega*A*cos(2*pi*omega*timestep*dt)
#
# xSideLB = 18
# tipVel = xSideLB*dangle_dt
#
# tipVelScaled = tipVel/(dt/dx) # scaled tip velocity in Paraview
#
# # check inlet velocity scaling in ParaView
# inletVelocity = 1
#
# inletVelocityLB = inletVelocity/(dx/dt) # scale it to LB units
# inletVelocityLBScaled = inletVelocityLB/(dt/dx) # scale it for ParaView to avoid too small quantities for velocity
# Out:
# \[
# \begin{aligned}
# A &= 0.785 \; \;\textrm{(oscillating amplitude)}
# \\[10pt]
# \omega &= 0.000 \; \;\textrm{(oscillating frequency)}
# \\[10pt]
# \mathrm{dt} &= 0.001 \;
# \\[10pt]
# \mathrm{dx} &= 0.111 \;
# \\[10pt]
# \mathrm{timestep} &= 500000.000 \; \;\textrm{(check the last time step)}
# \\[10pt]
# \mathrm{angle} &= 0.5 \cdot \pi + A \cdot \sin \left( 2 \cdot \pi \cdot \omega \cdot \mathrm{timestep} \cdot \mathrm{dt} \right) \\&= 0.5 \cdot 3.142 + 0.785 \cdot \sin \left( 2 \cdot 3.142 \cdot 0.000 \cdot 500000.000 \cdot 0.001 \right) \\&= 1.735  \\[10pt]
# \\[10pt]
# \mathrm{dangle}_{dt} &= 2 \cdot \pi \cdot \omega \cdot A \cdot \cos \left( 2 \cdot \pi \cdot \omega \cdot \mathrm{timestep} \cdot \mathrm{dt} \right) \\&= 2 \cdot 3.142 \cdot 0.000 \cdot 0.785 \cdot \cos \left( 2 \cdot 3.142 \cdot 0.000 \cdot 500000.000 \cdot 0.001 \right) \\&= 0.000  \\[10pt]
# \\[10pt]
# \mathrm{xSideLB} &= 18 \;
# \\[10pt]
# \mathrm{tipVel} &= \mathrm{xSideLB} \cdot \mathrm{dangle}_{dt}  = 18 \cdot 0.000 &= 0.007
# \\[10pt]
# \mathrm{tipVelScaled} &= \frac{ \mathrm{tipVel} }{ \frac{ \mathrm{dt} }{ \mathrm{dx} } }  = \frac{ 0.007 }{ \frac{ 0.001 }{ 0.111 } } &= 0.965 \; \;\textrm{(scaled tip velocity in Paraview)}
# \\[10pt]
# \mathrm{inletVelocity} &= 1 \;
# \\[10pt]
# \mathrm{inletVelocityLB} &= \frac{ \mathrm{inletVelocity} }{ \frac{ \mathrm{dx} }{ \mathrm{dt} } }  = \frac{ 1 }{ \frac{ 0.111 }{ 0.001 } } &= 0.007 \; \;\textrm{(scale it to LB units)}
# \\[10pt]
# \mathrm{inletVelocityLBScaled} &= \frac{ \mathrm{inletVelocityLB} }{ \frac{ \mathrm{dt} }{ \mathrm{dx} } }  = \frac{ 0.007 }{ \frac{ 0.001 }{ 0.111 } } &= 1.000 \; \;\textrm{(scale it for ParaView to avoid too small quantities for velocity)}
# \end{aligned}
# \]

# %% [markdown]
# # check
# 1. the scaled `inletVelocityLBScaled` is close to 1, as confirmed by the velocity slice close to the inlet
# ![image.png](attachment:image.png)
# 2. check the tip velocity at timestep 500000, it is close to 1 as well
# ![image-2.png](attachment:image-2.png)
