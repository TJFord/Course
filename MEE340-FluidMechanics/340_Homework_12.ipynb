# %%
pip install handcalcs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import handcalcs.render

from pint import UnitRegistry
u=UnitRegistry(auto_reduce_dimensions=True)

import math

# %% [markdown]
# ![hmw12.png](attachment:hmw12.png)
# ## Solution:
# For the function provided, generate the first four terms of the Taylor series expansion, estimate $f(x_0 + \Delta x)$, compare the result to the exact value of $e^{-0.1}$, and determine how many digits of accuracy was achieved with the Taylor series.
#
# ## Assumptions:
# Taylors series expansion:
# \begin{equation*}
# f(x_0 + \Delta x) = f(x_0) + (\dfrac{df}{dx})_{x=x_0}\Delta x + \dfrac{1}{2!}(\dfrac{d^2f}{dx^2})_{x=x_0}(\Delta x)^2 + \dfrac{1}{3!}(\dfrac{d^3f}{dx^3})_{x=x_0}(\Delta x)^3 + ...
# \end{equation*}
#
# Function:
# \begin{equation*}
# f(x) = exp(x) = e^x
# \end{equation*}

# %%
# %%render param
# x_0 = 0
# Delta_x = -0.1
# e = math.exp(1) #create the exponential variable with base
# Out:
# \[
# \begin{aligned}
# x_{0} &= 0 \;
#  &\Delta_{x} &= -0.100 \;
#  &e &= 2.718 \; \;\textrm{(create the exponential variable with base)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# Taylor series expansion:
# \begin{equation*}
# f(x_0 + \Delta x) = e^{x_0} + e^{x_0}\Delta x + \dfrac{1}{2}e^{x_0}(\Delta x)^2 + \dfrac{1}{3 \times 2}e^{x_0}(\Delta x)^3 + ...
# \end{equation*}

# %%
# %%render 10
# f = e**(x_0) + e**(x_0)*Delta_x + (1/2)*e**(x_0)*(Delta_x**2) + (1/(3*2))*e**(x_0)*(Delta_x**3)
# Out:
# \[
# \begin{aligned}
# f &= \left( e \right) ^{ x_{0} } + \left( e \right) ^{ x_{0} } \cdot \Delta_{x} + \left( \frac{ 1 }{ 2 } \right) \cdot \left( e \right) ^{ x_{0} } \cdot \left( \Delta_{x} \right) ^{ 2 } + \left( \frac{ 1 }{ 3 \cdot 2 } \right) \cdot \left( e \right) ^{ x_{0} } \cdot \left( \Delta_{x} \right) ^{ 3 } \\&= \left( 2.7182818285 \right) ^{ 0 } + \left( 2.7182818285 \right) ^{ 0 } \cdot -0.1000000000 + \left( \frac{ 1 }{ 2 } \right) \cdot \left( 2.7182818285 \right) ^{ 0 } \cdot \left( -0.1000000000 \right) ^{ 2 } + \left( \frac{ 1 }{ 3 \cdot 2 } \right) \cdot \left( 2.7182818285 \right) ^{ 0 } \cdot \left( -0.1000000000 \right) ^{ 3 } \\&= 0.9048333333  \\[10pt]
# \end{aligned}
# \]

# %%
# %%render 10
# exp = e**(-0.1)
# Out:
# \[
# \begin{aligned}
# \mathrm{exp} &= \left( e \right) ^{ \left( - 0.1 \right) }  = \left( 2.7182818285 \right) ^{ \left( - 0.1 \right) } &= 0.9048374180
# \end{aligned}
# \]

# %% [markdown]
# ## Discussion:
# By using the Taylor series expansion the estimation of $f(x_0 + \Delta x)$ is $0..9048333$, which compared to the exact value of $e^{-0.1}$ has around 5 digits of accuracy.
