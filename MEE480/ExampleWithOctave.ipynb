% %% [markdown]
% # How to call octave/matlab functions in JupyterNotebook
% 1. first, we need to let the jupyter notebook know where to find the source code. Here we save in the following folder
% 2. if you use nanohub, you can use `upload` button to upload them into the remote server.

% %%
% include the folder path to the code
addpath('/home/jifutan/Courses/MEE480/PlaneTruss') %

% %%
ls % you can check what files are in the current folder
% Out:
% Assemble.asv		       InputData.m     TrussResults.m
% Assemble.m		       InputGrid.m     Untitled.ipynb
% AssembleGlobalMatrix.asv       Main.m	       include_variables.m
% AssembleGlobalMatrix.m	       NodalSoln.m     postprocessor.m
% ExampleProblem-PlaneTruss.doc  PlotTruss.m     preprocessor.m
% ExampleWithOctave.ipynb        TrussElement.m

% %%
Main %directly run the Main.m file
% Out:
% K =
%
%  Columns 1 through 6:
%
%    8.5355e+07   3.5355e+07  -5.0000e+07            0            0            0
%    3.5355e+07   3.5355e+07            0            0            0            0
%   -5.0000e+07            0   8.5355e+07  -3.5355e+07            0            0
%             0            0  -3.5355e+07   1.0202e+08            0            0
%             0            0            0            0   7.1554e+07  -3.5777e+07
%             0            0            0            0  -3.5777e+07   1.7889e+07
%             0            0            0            0            0            0
%             0            0            0  -6.6667e+07            0            0
%   -3.5355e+07  -3.5355e+07  -3.5355e+07   3.5355e+07  -7.1554e+07   3.5777e+07
%   -3.5355e+07  -3.5355e+07   3.5355e+07  -3.5355e+07   3.5777e+07  -1.7889e+07
%
%  Columns 7 through 10:
%
%             0            0  -3.5355e+07  -3.5355e+07
%             0            0  -3.5355e+07  -3.5355e+07
% ...

% %%
a=5
% Out:
% a = 5

% %%
b=rand(10)
% Out:
% b =
%
%  Columns 1 through 6:
%
%    4.5521e-01   7.8001e-01   6.9252e-01   6.7887e-01   7.7433e-01   2.6059e-01
%    8.3106e-01   5.8095e-01   2.5151e-01   6.3702e-02   1.2887e-01   4.4132e-01
%    3.0817e-01   8.6068e-02   1.7593e-01   8.3065e-01   2.1180e-01   9.6741e-01
%    7.7683e-01   6.1484e-02   3.7805e-01   1.2499e-01   5.7708e-01   4.8492e-01
%    3.6909e-01   2.6917e-01   3.0290e-01   3.4130e-01   3.9452e-01   3.3607e-01
%    9.9758e-01   8.7693e-01   5.7834e-01   7.8471e-01   5.9330e-01   3.3307e-01
%    5.5338e-01   8.0804e-01   1.5667e-01   6.0915e-01   3.3031e-01   6.7316e-01
%    4.5312e-01   7.3620e-01   2.2957e-01   4.6032e-01   6.9734e-01   9.8958e-01
%    9.0816e-01   7.5647e-01   9.9514e-01   8.9003e-01   7.9203e-01   8.4615e-01
%    1.7887e-03   2.4736e-01   9.9547e-01   1.9338e-01   6.3847e-01   1.1446e-01
%
%  Columns 7 through 10:
%
%    9.0977e-01   5.3710e-01   4.7238e-01   8.9666e-01
%    2.6502e-01   3.4170e-01   4.8262e-01   3.2296e-01
% ...

% %% [markdown]
% \begin{bmatrix}
% 1 & 2 \\
% 3 & 4
% \end{bmatrix}

% %%
clear
