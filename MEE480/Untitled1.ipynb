% %% [markdown]
% # visualize the shape function for a beam

% %%
clear
xi = -1:.1:1
N1 = 1/4*(1-xi).^2.*(2+xi)
figure;
plot(xi,N1)
axis equal
xlabel('\xi')
ylabel('N1')
% Out:
% xi =
%
%  Columns 1 through 8:
%
%    -1.0000   -0.9000   -0.8000   -0.7000   -0.6000   -0.5000   -0.4000   -0.3000
%
%  Columns 9 through 16:
%
%    -0.2000   -0.1000         0    0.1000    0.2000    0.3000    0.4000    0.5000
%
%  Columns 17 through 21:
%
%     0.6000    0.7000    0.8000    0.9000    1.0000
%
% N1 =
%
%  Columns 1 through 8:
%
%    1.0000   0.9928   0.9720   0.9392   0.8960   0.8438   0.7840   0.7182
%
%  Columns 9 through 16:
%
%    0.6480   0.5748   0.5000   0.4252   0.3520   0.2817   0.2160   0.1562
%
%  Columns 17 through 21:
%
%    0.1040   0.0607   0.0280   0.0072        0
